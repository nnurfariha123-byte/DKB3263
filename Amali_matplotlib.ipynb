# %% [markdown]
# <a href="https://colab.research.google.com/github/nnurfariha123-byte/DKB3263/blob/main/Amali_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Amali matplotlib

# %%
plt.bar(df["Nama"], df["Markah"])
plt.title("Markah Pelajar")
plt.xlabel("Nama Pelajar")
plt.ylabel("Markah")
plt.show()

plt.plot(df["Nama"], df["Markah"], marker="o")
plt.title("Prestasi Markah Pelajar")
plt.xlabel("Nama Pelajar")
plt.ylabel("Markah")
plt.show()

plt.hist(df["Markah"], bins=5)
plt.title("Taburan Markah Pelajar")
plt.xlabel("Julat Markah")
plt.ylabel("Bilangan Pelajar")
plt.show()

# Define grade boundaries and labels
bins = [0, 50, 60, 70, 80, 100]
labels = ['F', 'D', 'C', 'B', 'A']

# Create the 'Gred' column
df['Gred'] = pd.cut(df['Markah'], bins=bins, labels=labels, right=False)

jumlah_gred = df["Gred"].value_counts()
plt.pie(
jumlah_gred,
labels=jumlah_gred.index,
autopct="%1.1f%%"
)
plt.title("Peratusan Gred Pelajar")
plt.show()

# %% [markdown]
# Bahagian E: Gabungan NumPy, pandas dan matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = {
"Nama": ["Ali", "Siti", "Kumar", "Mei Ling", "Aiman"],
"Markah": [70, 85, 90, 65, 80]
}
df = pd.DataFrame(data)

purata = np.mean(df["Markah"])
tertinggi = np.max(df["Markah"])
terendah = np.min(df["Markah"])
print("Purata:", purata)
print("Markah tertinggi:", tertinggi)
print("Markah terendah:", terendah)

df["Status"] = np.where(df["Markah"] >= 50, "Lulus", "Gagal")
print(df)
plt.bar(df["Nama"], df["Markah"])
plt.axhline(
y=purata,
linestyle="--",
label="Purata"
)
plt.title("Analisis Markah Pelajar")
plt.xlabel("Nama Pelajar")
plt.ylabel("Markah")
plt.legend()
plt.show()
# Out:
# Purata: 78.0
# Markah tertinggi: 90
# Markah terendah: 65
#        Nama  Markah Status
# 0       Ali      70  Lulus
# 1      Siti      85  Lulus
# 2     Kumar      90  Lulus
# 3  Mei Ling      65  Lulus
# 4     Aiman      80  Lulus
